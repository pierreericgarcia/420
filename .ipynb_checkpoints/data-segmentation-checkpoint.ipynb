# %% [markdown]
# # How I'll split the data
#
# - Training data : 64%
# - Validation data : 16%
# - Testing data : 20%

# %%
import os
import glob
import math
import errno
import shutil 

current_path = os.getcwd()

# %%
root = '/Users/docteur/notebooks/420/testDatasets6/'

# %%
stains_folders = glob.glob('{}*/*'.format(root))
stains_folders
# Out:
# ['/Users/docteur/notebooks/420/testDatasets6/sativa/burger',
#  '/Users/docteur/notebooks/420/testDatasets6/sativa/sushi',
#  '/Users/docteur/notebooks/420/testDatasets6/sativa/pizza',
#  '/Users/docteur/notebooks/420/testDatasets6/indica/metro',
#  '/Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge',
#  '/Users/docteur/notebooks/420/testDatasets6/indica/building',
#  '/Users/docteur/notebooks/420/testDatasets6/hybrid/arbre',
#  '/Users/docteur/notebooks/420/testDatasets6/hybrid/plante',
#  '/Users/docteur/notebooks/420/testDatasets6/hybrid/foret']

# %%
training_ratio = 0.64
validation_ratio = 0.16
testing_ratio = 0.2

for current_strain in stains_folders:
    images_in_current_strain = glob.glob('{}/*'.format(current_strain))
    
    train_length = math.ceil(len(images_in_current_strain) * training_ratio)
    validation_length = math.ceil(len(images_in_current_strain) * validation_ratio)
    test_length = math.ceil(len(images_in_current_strain) * testing_ratio)
    
    datasets_split = [
        { 'label': 'train', 'range': range(train_length) }, 
        { 'label': 'valid', 'range': range(train_length, (train_length + validation_length)) }, 
        { 'label': 'test', 'range': range((train_length + validation_length), (train_length + validation_length + test_length)) }
    ]
    
    for split in datasets_split:
        
        current_range = range
        
        for index in split['range']:
            if len(images_in_current_strain) > index:
                
                old_path = images_in_current_strain[index]
                
                new_path = images_in_current_strain[index].split(root)
                new_path[0] = '{}{}'.format(root, split['label'])
                new_path = '/'.join(new_path)

                if not os.path.exists(os.path.dirname(new_path)):
                    try:
                        os.makedirs(os.path.dirname(new_path))
                    except OSError as exc:
                        if exc.errno != errno.EEXIST:
                            raise
                
                shutil.move(old_path, new_path)
# Out:
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/sushi/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/sativa/pizza/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/metro/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/feuxrouge/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/indica/building/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/arbre/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/plante/1copie16.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie6.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie7.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie5.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie18.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie19.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie4.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie20.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie3.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie2.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie12.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie13.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie11.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie10.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie9.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie14.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie15.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie8.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie17.png True
# /Users/docteur/notebooks/420/testDatasets6/hybrid/foret/1copie16.png True

# %%
array = [1, 2, 3, 4, 5]

if len(array) > 5:
    print('hey')

# %%
os.rename("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
